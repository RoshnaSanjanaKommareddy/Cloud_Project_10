# %%
import pandas as pd
import boto3
import sagemaker
from sklearn.model_selection import train_test_split
from sagemaker import get_execution_role
from sagemaker.amazon.amazon_estimator import get_image_uri
from sagemaker.inputs import TrainingInput

# %%
bucket='cosyneraw'
data_key = 'cell_metrics.csv'
data_location = 's3://{}/{}'.format(bucket, data_key)

df= pd.read_csv(data_location)
df
# Out:
#      Unnamed: 0    cell_id   Cre   area    expt_id  signal_correlation_dg  \
# 0             0  598998745   Sst   VISl  597028936               0.351210
# 1             1  662056046   Sst   VISp  612044633               0.383254
# 2             2  662098491   Sst  VISpm  639117194               0.115936
# 3             3  606133820   Sst  VISpm  601273919               0.238630
# 4             4  662099083   Sst   VISl  593337825               0.327079
# ..          ...        ...   ...    ...        ...                    ...
# 111         111  585736587  Emx1   VISl  583136565               0.134566
# 112         112  578387999  Emx1   VISl  573261513               0.137884
# 113         113  570927169  Emx1  VISal  562536151               0.096853
# 114         114  605627126  Emx1   VISp  595263152               0.159767
# 115         115  562753051  Emx1   VISp  561312433               0.081558
#
#      signal_correlation_nm3  number_cells  imaging_depth    age     sex  \
# 0                  0.074539           NaN          375.0  105.0  female
# 1                  0.139712           NaN          265.0   98.0    male
# 2                  0.115184           NaN          375.0   98.0    male
# 3                  0.082120           NaN          275.0  117.0  female
# 4                  0.224116           NaN          275.0  138.0  female
# ..                      ...           ...            ...    ...     ...
# 111                0.032729           NaN          175.0  104.0    male
# 112                0.045017           NaN          275.0   87.0    male
# 113                0.069860           NaN          375.0  111.0  female
# 114                0.060545           NaN          375.0  122.0    male
# 115                0.055286           NaN          275.0   87.0  female
#
#      numbercells
# 0           12.0
# 1            8.0
# 2            7.0
# 3           12.0
# 4           17.0
# ..           ...
# 111         49.0
# 112        327.0
# 113        123.0
# 114        221.0
# 115        302.0
#
# [116 rows x 12 columns]

# %%
del df['number_cells']
del df['Unnamed: 0']
del df['cell_id']
del df['expt_id']
del df['Cre']
del df['area']

df['sex'] = df['sex'].map({'male': 1, 'female': 0})

# %%
cols = df.columns.tolist()
cols = cols[-1:] + cols[:-1]
df = df[cols]

# %%
df['numbercells'].value_counts()
# Out:
# numbercells
# 52.0     4
# 21.0     3
# 82.0     3
# 105.0    3
# 12.0     2
#         ..
# 8.0      1
# 115.0    1
# 232.0    1
# 286.0    1
# 221.0    1
# Name: count, Length: 83, dtype: int64

# %%
from sklearn.model_selection import train_test_split
train, test_and_validate = train_test_split(df, test_size=0.2, random_state=42)

# %%
test, validate = train_test_split(test_and_validate, test_size=0.5, random_state=42)

# %%
print(train.shape)
print(test.shape)
print(validate.shape)
# Out:
# (92, 6)
# (12, 6)
# (12, 6)

# %%
print(train['numbercells'].value_counts())
print(test['numbercells'].value_counts())
print(validate['numbercells'].value_counts())
# Out:
# numbercells
# 82.0     3
# 51.0     2
# 67.0     2
# 10.0     2
# 128.0    2
#         ..
# 87.0     1
# 12.0     1
# 58.0     1
# 15.0     1
# 80.0     1
# Name: count, Length: 70, dtype: int64
# numbercells
# 12.0     1
# 95.0     1
# 237.0    1
# 41.0     1
# 21.0     1
# 52.0     1
# 284.0    1
# 15.0     1
# 140.0    1
# 65.0     1
# 103.0    1
# 105.0    1
# Name: count, dtype: int64
# numbercells
# 97.0     1
# 286.0    1
# 91.0     1
# 102.0    1
# 52.0     1
# 171.0    1
# 115.0    1
# 17.0     1
# 103.0    1
# 226.0    1
# 90.0     1
# 275.0    1
# Name: count, dtype: int64

# %%
train.to_csv('train.csv', header=False, index=False)
validate.to_csv('validate.csv', header=False, index=False)
test.to_csv('test.csv', header=False, index=False)

# %%
bucket = 'cosyneraw'
prefix = 'ttv'

# %%
sess = sagemaker.Session()

# Upload the files to S3
s3_train = sess.upload_data('train.csv', bucket=bucket, key_prefix=f'{prefix}/train')
s3_validation = sess.upload_data('validate.csv', bucket=bucket, key_prefix=f'{prefix}/validate')
s3_test = sess.upload_data('test.csv', bucket=bucket, key_prefix=f'{prefix}/test')
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml

# %%
role = "arn:aws:iam::153395555780:role/LabRole"
container = get_image_uri(boto3.Session().region_name, 'linear-learner')
# Out:
# WARNING:sagemaker.deprecations:The method get_image_uri has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# INFO:sagemaker.image_uris:Same images used for training and inference. Defaulting to image scope: inference.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.

# %%
linear = sagemaker.estimator.Estimator(container,
                                       role, 
                                       instance_count=1, 
                                       instance_type='ml.m4.xlarge',
                                       output_path=f's3://{bucket}/{prefix}/output',
                                       sagemaker_session=sess)
linear.set_hyperparameters(feature_dim=5,
                           predictor_type='regressor',
                           mini_batch_size=20)

# %%
data_channels = {
    'train': TrainingInput(s3_train, content_type='text/csv'),
    'validation': TrainingInput(s3_validation, content_type='text/csv')
    # 'test' channel is optional and is not typically used during training
}

# Fit the model
linear.fit(inputs=data_channels)
# Out:
# INFO:sagemaker:Creating training-job with name: linear-learner-2023-12-03-23-52-51-070
# 2023-12-03 23:52:51 Starting - Starting the training job...
# 2023-12-03 23:53:06 Starting - Preparing the instances for training.........
# 2023-12-03 23:54:24 Downloading - Downloading input data...
# 2023-12-03 23:55:09 Training - Downloading the training image.........
# 2023-12-03 23:56:50 Uploading - Uploading generated training modelDocker entrypoint called with argument(s): train
# Running default environment configuration script
# [12/03/2023 23:56:38 INFO 140583242454848] Reading default configuration from /opt/amazon/lib/python3.8/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [12/03/2023 23:56:38 INFO 140583242454848] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '5', 'mini_batch_size': '20', 'predictor_type': 'regressor'}
# [12/03/2023 23:56:38 INFO 140583242454848] Final configuration: {'mini_batch_size': '20', 'epochs': '15', 'feature_dim': '5', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'regressor'}
# /opt/amazon/lib/python3.8/site-packages/mxnet/model.py:97: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if num_device is 1 and 'dist' not in kvstore:
# /opt/amazon/lib/python3.8/site-packages/scipy/optimize/_shgo.py:495: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if cons['type'] is 'ineq':
# /opt/amazon/lib/python3.8/site-packages/scipy/optimize/_shgo.py:743: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if len(self.X_min) is not 0:
# [12/03/2023 23:56:42 WARNING 140583242454848] Loggers have already been setup.
# [12/03/2023 23:56:42 INFO 140583242454848] Final configuration: {'mini_batch_size': '20', 'epochs': '15', 'feature_dim': '5', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'regressor'}
# [12/03/2023 23:56:42 WARNING 140583242454848] Loggers have already been setup.
# Process 7 is a worker.
# [12/03/2023 23:56:42 INFO 140583242454848] Using default worker.
# [12/03/2023 23:56:42 INFO 140583242454848] Checkpoint loading and saving are disabled.
# [12/03/2023 23:56:42 INFO 140583242454848] Create Store: local
# [12/03/2023 23:56:42 INFO 140583242454848] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7fdb86113e80>
# [12/03/2023 23:56:42 INFO 140583242454848] Scaling model computed with parameters:
#  {'stdev_label':
# [104.81002]
# <NDArray 1 @cpu(0)>, 'stdev_weight':
# [1.0922144e-01 6.2862009e-02 1.0661320e+02 1.4987448e+01 4.9749371e-01]
# <NDArray 5 @cpu(0)>, 'mean_label':
# [129.31252]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [1.5614553e-01 5.9566539e-02 3.1143750e+02 1.0253750e+02 5.5000001e-01]
# <NDArray 5 @cpu(0)>}
# /opt/amazon/python3.8/lib/python3.8/subprocess.py:848: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdout = io.open(c2pread, 'rb', bufsize)
# [12/03/2023 23:56:42 INFO 140583242454848] nvidia-smi: took 0.034 seconds to run.
# [12/03/2023 23:56:42 INFO 140583242454848] nvidia-smi identified 0 GPUs.
# [12/03/2023 23:56:42 INFO 140583242454848] Number of GPUs being used: 0
# #metrics {"StartTime": 1701647802.6495838, "EndTime": 1701647802.6496372, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 112.0, "count": 1, "min": 112, "max": 112}, "Total Batches Seen": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Max Records Seen Between Resets": {"sum": 92.0, "count": 1, "min": 92, "max": 92}, "Max Batches Seen Between Resets": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# #metrics {"StartTime": 1701647802.7501802, "EndTime": 1701647802.75025, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_mse_objective": {"sum": 1.008765959739685, "count": 1, "min": 1.008765959739685, "max": 1.008765959739685}}}
# #metrics {"StartTime": 1701647802.750331, "EndTime": 1701647802.7503424, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_mse_objective": {"sum": 0.9764539718627929, "count": 1, "min": 0.9764539718627929, "max": 0.9764539718627929}}}
# #metrics {"StartTime": 1701647802.7503793, "EndTime": 1701647802.750391, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_mse_objective": {"sum": 1.03967125415802, "count": 1, "min": 1.03967125415802, "max": 1.03967125415802}}}
# #metrics {"StartTime": 1701647802.7504442, "EndTime": 1701647802.7504568, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_mse_objective": {"sum": 1.04042090177536, "count": 1, "min": 1.04042090177536, "max": 1.04042090177536}}}
# #metrics {"StartTime": 1701647802.750505, "EndTime": 1701647802.7505167, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_mse_objective": {"sum": 1.2959120273590088, "count": 1, "min": 1.2959120273590088, "max": 1.2959120273590088}}}
# #metrics {"StartTime": 1701647802.7505722, "EndTime": 1701647802.7505856, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_mse_objective": {"sum": 1.2801149725914, "count": 1, "min": 1.2801149725914, "max": 1.2801149725914}}}
# #metrics {"StartTime": 1701647802.750636, "EndTime": 1701647802.7506511, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_mse_objective": {"sum": 1.2589629411697387, "count": 1, "min": 1.2589629411697387, "max": 1.2589629411697387}}}
# #metrics {"StartTime": 1701647802.7507055, "EndTime": 1701647802.7507176, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_mse_objective": {"sum": 1.2573224306106567, "count": 1, "min": 1.2573224306106567, "max": 1.2573224306106567}}}
# #metrics {"StartTime": 1701647802.7507734, "EndTime": 1701647802.7507856, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_mse_objective": {"sum": 0.990478229522705, "count": 1, "min": 0.990478229522705, "max": 0.990478229522705}}}
# #metrics {"StartTime": 1701647802.7508392, "EndTime": 1701647802.7508519, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_mse_objective": {"sum": 1.0207197427749635, "count": 1, "min": 1.0207197427749635, "max": 1.0207197427749635}}}
# #metrics {"StartTime": 1701647802.7509065, "EndTime": 1701647802.750919, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_mse_objective": {"sum": 1.036209487915039, "count": 1, "min": 1.036209487915039, "max": 1.036209487915039}}}
# #metrics {"StartTime": 1701647802.7509682, "EndTime": 1701647802.750981, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_mse_objective": {"sum": 1.0012103915214539, "count": 1, "min": 1.0012103915214539, "max": 1.0012103915214539}}}
# #metrics {"StartTime": 1701647802.7510328, "EndTime": 1701647802.751046, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_mse_objective": {"sum": 1.2460769653320312, "count": 1, "min": 1.2460769653320312, "max": 1.2460769653320312}}}
# #metrics {"StartTime": 1701647802.7511046, "EndTime": 1701647802.7511177, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_mse_objective": {"sum": 1.2469683170318604, "count": 1, "min": 1.2469683170318604, "max": 1.2469683170318604}}}
# #metrics {"StartTime": 1701647802.7511833, "EndTime": 1701647802.751198, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_mse_objective": {"sum": 1.2879239439964294, "count": 1, "min": 1.2879239439964294, "max": 1.2879239439964294}}}
# #metrics {"StartTime": 1701647802.7512546, "EndTime": 1701647802.7512693, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_mse_objective": {"sum": 1.250504446029663, "count": 1, "min": 1.250504446029663, "max": 1.250504446029663}}}
# #metrics {"StartTime": 1701647802.751323, "EndTime": 1701647802.7513359, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"train_mse_objective": {"sum": 0.9656409740447998, "count": 1, "min": 0.9656409740447998, "max": 0.9656409740447998}}}
# #metrics {"StartTime": 1701647802.7513893, "EndTime": 1701647802.7514029, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"train_mse_objective": {"sum": 1.0156918048858643, "count": 1, "min": 1.0156918048858643, "max": 1.0156918048858643}}}
# #metrics {"StartTime": 1701647802.7514534, "EndTime": 1701647802.7514663, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"train_mse_objective": {"sum": 1.0461467385292054, "count": 1, "min": 1.0461467385292054, "max": 1.0461467385292054}}}
# #metrics {"StartTime": 1701647802.7515202, "EndTime": 1701647802.7515347, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"train_mse_objective": {"sum": 0.9705569744110107, "count": 1, "min": 0.9705569744110107, "max": 0.9705569744110107}}}
# #metrics {"StartTime": 1701647802.751585, "EndTime": 1701647802.751598, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"train_mse_objective": {"sum": 1.2839355945587159, "count": 1, "min": 1.2839355945587159, "max": 1.2839355945587159}}}
# #metrics {"StartTime": 1701647802.7516472, "EndTime": 1701647802.7516599, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"train_mse_objective": {"sum": 1.2209715247154236, "count": 1, "min": 1.2209715247154236, "max": 1.2209715247154236}}}
# #metrics {"StartTime": 1701647802.751705, "EndTime": 1701647802.7517183, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"train_mse_objective": {"sum": 1.2959305763244628, "count": 1, "min": 1.2959305763244628, "max": 1.2959305763244628}}}
# #metrics {"StartTime": 1701647802.7517674, "EndTime": 1701647802.75178, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"train_mse_objective": {"sum": 1.2742131710052491, "count": 1, "min": 1.2742131710052491, "max": 1.2742131710052491}}}
# #metrics {"StartTime": 1701647802.751875, "EndTime": 1701647802.7518895, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"train_mse_objective": {"sum": 0.9931712865829467, "count": 1, "min": 0.9931712865829467, "max": 0.9931712865829467}}}
# #metrics {"StartTime": 1701647802.751942, "EndTime": 1701647802.7519557, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"train_mse_objective": {"sum": 1.053477144241333, "count": 1, "min": 1.053477144241333, "max": 1.053477144241333}}}
# #metrics {"StartTime": 1701647802.7520063, "EndTime": 1701647802.7520192, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"train_mse_objective": {"sum": 0.9948275804519653, "count": 1, "min": 0.9948275804519653, "max": 0.9948275804519653}}}
# #metrics {"StartTime": 1701647802.7520633, "EndTime": 1701647802.7520738, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"train_mse_objective": {"sum": 1.014584469795227, "count": 1, "min": 1.014584469795227, "max": 1.014584469795227}}}
# #metrics {"StartTime": 1701647802.7521267, "EndTime": 1701647802.7521396, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"train_mse_objective": {"sum": 1.3339393615722657, "count": 1, "min": 1.3339393615722657, "max": 1.3339393615722657}}}
# #metrics {"StartTime": 1701647802.7521877, "EndTime": 1701647802.7522001, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 1.2797929883003234, "count": 1, "min": 1.2797929883003234, "max": 1.2797929883003234}}}
# #metrics {"StartTime": 1701647802.752249, "EndTime": 1701647802.752262, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 1.3057172417640686, "count": 1, "min": 1.3057172417640686, "max": 1.3057172417640686}}}
# #metrics {"StartTime": 1701647802.7523074, "EndTime": 1701647802.7523193, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 1.3100915908813477, "count": 1, "min": 1.3100915908813477, "max": 1.3100915908813477}}}
# [12/03/2023 23:56:42 INFO 140583242454848] #quality_metric: host=algo-1, epoch=0, train mse_objective <loss>=1.008765959739685
# #metrics {"StartTime": 1701647802.804437, "EndTime": 1701647802.8045342, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"validation_mse_objective": {"sum": 6846.673177083333, "count": 1, "min": 6846.673177083333, "max": 6846.673177083333}}}
# #metrics {"StartTime": 1701647802.8046324, "EndTime": 1701647802.8046472, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"validation_mse_objective": {"sum": 6604.654296875, "count": 1, "min": 6604.654296875, "max": 6604.654296875}}}
# #metrics {"StartTime": 1701647802.8047054, "EndTime": 1701647802.8047202, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"validation_mse_objective": {"sum": 7252.593098958333, "count": 1, "min": 7252.593098958333, "max": 7252.593098958333}}}
# #metrics {"StartTime": 1701647802.8047774, "EndTime": 1701647802.8047867, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"validation_mse_objective": {"sum": 6156.809895833333, "count": 1, "min": 6156.809895833333, "max": 6156.809895833333}}}
# #metrics {"StartTime": 1701647802.8048239, "EndTime": 1701647802.8048317, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"validation_mse_objective": {"sum": 10870.501302083334, "count": 1, "min": 10870.501302083334, "max": 10870.501302083334}}}
# #metrics {"StartTime": 1701647802.8048677, "EndTime": 1701647802.8048792, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"validation_mse_objective": {"sum": 11564.03125, "count": 1, "min": 11564.03125, "max": 11564.03125}}}
# #metrics {"StartTime": 1701647802.804923, "EndTime": 1701647802.804934, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"validation_mse_objective": {"sum": 12012.912760416666, "count": 1, "min": 12012.912760416666, "max": 12012.912760416666}}}
# #metrics {"StartTime": 1701647802.8049767, "EndTime": 1701647802.8049884, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"validation_mse_objective": {"sum": 11918.6796875, "count": 1, "min": 11918.6796875, "max": 11918.6796875}}}
# #metrics {"StartTime": 1701647802.8050444, "EndTime": 1701647802.8050578, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"validation_mse_objective": {"sum": 7177.317708333333, "count": 1, "min": 7177.317708333333, "max": 7177.317708333333}}}
# #metrics {"StartTime": 1701647802.8051128, "EndTime": 1701647802.8051264, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"validation_mse_objective": {"sum": 6221.260416666667, "count": 1, "min": 6221.260416666667, "max": 6221.260416666667}}}
# #metrics {"StartTime": 1701647802.8051822, "EndTime": 1701647802.8051944, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"validation_mse_objective": {"sum": 6715.0390625, "count": 1, "min": 6715.0390625, "max": 6715.0390625}}}
# #metrics {"StartTime": 1701647802.805248, "EndTime": 1701647802.8052595, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"validation_mse_objective": {"sum": 6237.486979166667, "count": 1, "min": 6237.486979166667, "max": 6237.486979166667}}}
# #metrics {"StartTime": 1701647802.805312, "EndTime": 1701647802.8053243, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"validation_mse_objective": {"sum": 11585.834635416666, "count": 1, "min": 11585.834635416666, "max": 11585.834635416666}}}
# #metrics {"StartTime": 1701647802.8053713, "EndTime": 1701647802.805385, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"validation_mse_objective": {"sum": 11698.8046875, "count": 1, "min": 11698.8046875, "max": 11698.8046875}}}
# #metrics {"StartTime": 1701647802.8054397, "EndTime": 1701647802.8054538, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"validation_mse_objective": {"sum": 11129.184895833334, "count": 1, "min": 11129.184895833334, "max": 11129.184895833334}}}
# #metrics {"StartTime": 1701647802.8055084, "EndTime": 1701647802.805522, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"validation_mse_objective": {"sum": 11852.194010416666, "count": 1, "min": 11852.194010416666, "max": 11852.194010416666}}}
# #metrics {"StartTime": 1701647802.8055758, "EndTime": 1701647802.8055892, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"validation_mse_objective": {"sum": 6869.878255208333, "count": 1, "min": 6869.878255208333, "max": 6869.878255208333}}}
# #metrics {"StartTime": 1701647802.8056397, "EndTime": 1701647802.8056521, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"validation_mse_objective": {"sum": 7009.013671875, "count": 1, "min": 7009.013671875, "max": 7009.013671875}}}
# #metrics {"StartTime": 1701647802.8056924, "EndTime": 1701647802.8057058, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"validation_mse_objective": {"sum": 6633.280598958333, "count": 1, "min": 6633.280598958333, "max": 6633.280598958333}}}
# #metrics {"StartTime": 1701647802.8057587, "EndTime": 1701647802.8057733, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"validation_mse_objective": {"sum": 6383.643880208333, "count": 1, "min": 6383.643880208333, "max": 6383.643880208333}}}
# #metrics {"StartTime": 1701647802.805831, "EndTime": 1701647802.8058453, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"validation_mse_objective": {"sum": 11802.434895833334, "count": 1, "min": 11802.434895833334, "max": 11802.434895833334}}}
# #metrics {"StartTime": 1701647802.8058987, "EndTime": 1701647802.8059127, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"validation_mse_objective": {"sum": 12130.3671875, "count": 1, "min": 12130.3671875, "max": 12130.3671875}}}
# #metrics {"StartTime": 1701647802.8059642, "EndTime": 1701647802.805978, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"validation_mse_objective": {"sum": 12093.756510416666, "count": 1, "min": 12093.756510416666, "max": 12093.756510416666}}}
# #metrics {"StartTime": 1701647802.8060267, "EndTime": 1701647802.8060403, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"validation_mse_objective": {"sum": 11385.912760416666, "count": 1, "min": 11385.912760416666, "max": 11385.912760416666}}}
# #metrics {"StartTime": 1701647802.8060956, "EndTime": 1701647802.8061097, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"validation_mse_objective": {"sum": 6893.920572916667, "count": 1, "min": 6893.920572916667, "max": 6893.920572916667}}}
# #metrics {"StartTime": 1701647802.8061628, "EndTime": 1701647802.8061757, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"validation_mse_objective": {"sum": 6790.915364583333, "count": 1, "min": 6790.915364583333, "max": 6790.915364583333}}}
# #metrics {"StartTime": 1701647802.8062315, "EndTime": 1701647802.8062446, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"validation_mse_objective": {"sum": 6949.529947916667, "count": 1, "min": 6949.529947916667, "max": 6949.529947916667}}}
# #metrics {"StartTime": 1701647802.8062947, "EndTime": 1701647802.8063087, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"validation_mse_objective": {"sum": 6883.302734375, "count": 1, "min": 6883.302734375, "max": 6883.302734375}}}
# #metrics {"StartTime": 1701647802.8063602, "EndTime": 1701647802.806374, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"validation_mse_objective": {"sum": 13222.575520833334, "count": 1, "min": 13222.575520833334, "max": 13222.575520833334}}}
# #metrics {"StartTime": 1701647802.8064275, "EndTime": 1701647802.80644, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"validation_mse_objective": {"sum": 12359.9296875, "count": 1, "min": 12359.9296875, "max": 12359.9296875}}}
# #metrics {"StartTime": 1701647802.806492, "EndTime": 1701647802.8065052, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"validation_mse_objective": {"sum": 12193.87109375, "count": 1, "min": 12193.87109375, "max": 12193.87109375}}}
# #metrics {"StartTime": 1701647802.8065608, "EndTime": 1701647802.8065734, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"validation_mse_objective": {"sum": 13273.994791666666, "count": 1, "min": 13273.994791666666, "max": 13273.994791666666}}}
# [12/03/2023 23:56:42 INFO 140583242454848] #quality_metric: host=algo-1, epoch=0, validation mse_objective <loss>=6846.673177083333
# [12/03/2023 23:56:42 INFO 140583242454848] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=mse_objective, value=6156.809895833333
# [12/03/2023 23:56:42 INFO 140583242454848] Epoch 0: Loss improved. Updating best model
# [12/03/2023 23:56:42 INFO 140583242454848] Saving model for epoch: 0
# [12/03/2023 23:56:42 INFO 140583242454848] Saved checkpoint to "/tmp/tmp4eg9d1p2/mx-mod-0000.params"
# [12/03/2023 23:56:42 INFO 140583242454848] #progress_metric: host=algo-1, completed 6.666666666666667 % of epochs
# #metrics {"StartTime": 1701647802.6499627, "EndTime": 1701647802.8154275, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 204.0, "count": 1, "min": 204, "max": 204}, "Total Batches Seen": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Max Records Seen Between Resets": {"sum": 92.0, "count": 1, "min": 92, "max": 92}, "Max Batches Seen Between Resets": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 92.0, "count": 1, "min": 92, "max": 92}, "Number of Batches Since Last Reset": {"sum": 5.0, "count": 1, "min": 5, "max": 5}}}
# [12/03/2023 23:56:42 INFO 140583242454848] #throughput_metric: host=algo-1, train throughput=555.4681798683146 records/second
# #metrics {"StartTime": 1701647802.9232087, "EndTime": 1701647802.9232688, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_mse_objective": {"sum": 0.9811383247375488, "count": 1, "min": 0.9811383247375488, "max": 0.9811383247375488}}}
# #metrics {"StartTime": 1701647802.9233477, "EndTime": 1701647802.9233603, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_mse_objective": {"sum": 0.9501364827156067, "count": 1, "min": 0.9501364827156067, "max": 0.9501364827156067}}}
# #metrics {"StartTime": 1701647802.9234064, "EndTime": 1701647802.9234195, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_mse_objective": {"sum": 1.0065091371536254, "count": 1, "min": 1.0065091371536254, "max": 1.0065091371536254}}}
# #metrics {"StartTime": 1701647802.9234753, "EndTime": 1701647802.923488, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_mse_objective": {"sum": 1.009098219871521, "count": 1, "min": 1.009098219871521, "max": 1.009098219871521}}}
# #metrics {"StartTime": 1701647802.923543, "EndTime": 1701647802.923556, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_mse_objective": {"sum": 1.2289027929306031, "count": 1, "min": 1.2289027929306031, "max": 1.2289027929306031}}}
# #metrics {"StartTime": 1701647802.9236104, "EndTime": 1701647802.9236233, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_mse_objective": {"sum": 1.270530343055725, "count": 1, "min": 1.270530343055725, "max": 1.270530343055725}}}
# #metrics {"StartTime": 1701647802.9236786, "EndTime": 1701647802.923693, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_mse_objective": {"sum": 1.3017406225204469, "count": 1, "min": 1.3017406225204469, "max": 1.3017406225204469}}}
# #metrics {"StartTime": 1701647802.9237428, "EndTime": 1701647802.9237566, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_mse_objective": {"sum": 1.3085996866226197, "count": 1, "min": 1.3085996866226197, "max": 1.3085996866226197}}}
# #metrics {"StartTime": 1701647802.9238405, "EndTime": 1701647802.9238548, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_mse_objective": {"sum": 0.9596834659576416, "count": 1, "min": 0.9596834659576416, "max": 0.9596834659576416}}}
# #metrics {"StartTime": 1701647802.9239101, "EndTime": 1701647802.923924, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_mse_objective": {"sum": 0.9903786063194275, "count": 1, "min": 0.9903786063194275, "max": 0.9903786063194275}}}
# #metrics {"StartTime": 1701647802.923975, "EndTime": 1701647802.9239883, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_mse_objective": {"sum": 1.0064178824424743, "count": 1, "min": 1.0064178824424743, "max": 1.0064178824424743}}}
# #metrics {"StartTime": 1701647802.9240313, "EndTime": 1701647802.924043, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_mse_objective": {"sum": 0.9738684177398682, "count": 1, "min": 0.9738684177398682, "max": 0.9738684177398682}}}
# #metrics {"StartTime": 1701647802.9241, "EndTime": 1701647802.9241123, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_mse_objective": {"sum": 1.2524116396903993, "count": 1, "min": 1.2524116396903993, "max": 1.2524116396903993}}}
# #metrics {"StartTime": 1701647802.9241633, "EndTime": 1701647802.924177, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_mse_objective": {"sum": 1.2701293110847474, "count": 1, "min": 1.2701293110847474, "max": 1.2701293110847474}}}
# #metrics {"StartTime": 1701647802.9242318, "EndTime": 1701647802.9242444, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_mse_objective": {"sum": 1.24612877368927, "count": 1, "min": 1.24612877368927, "max": 1.24612877368927}}}
# #metrics {"StartTime": 1701647802.924292, "EndTime": 1701647802.9243052, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_mse_objective": {"sum": 1.260889434814453, "count": 1, "min": 1.260889434814453, "max": 1.260889434814453}}}
# #metrics {"StartTime": 1701647802.924353, "EndTime": 1701647802.9243655, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_mse_objective": {"sum": 0.9421197056770325, "count": 1, "min": 0.9421197056770325, "max": 0.9421197056770325}}}
# #metrics {"StartTime": 1701647802.9244168, "EndTime": 1701647802.9244306, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_mse_objective": {"sum": 0.9885509252548218, "count": 1, "min": 0.9885509252548218, "max": 0.9885509252548218}}}
# #metrics {"StartTime": 1701647802.9244964, "EndTime": 1701647802.924511, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_mse_objective": {"sum": 1.013545024394989, "count": 1, "min": 1.013545024394989, "max": 1.013545024394989}}}
# #metrics {"StartTime": 1701647802.9245698, "EndTime": 1701647802.9245832, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_mse_objective": {"sum": 0.9466598510742188, "count": 1, "min": 0.9466598510742188, "max": 0.9466598510742188}}}
# #metrics {"StartTime": 1701647802.924642, "EndTime": 1701647802.9246564, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_mse_objective": {"sum": 1.2696516990661622, "count": 1, "min": 1.2696516990661622, "max": 1.2696516990661622}}}
# #metrics {"StartTime": 1701647802.9247048, "EndTime": 1701647802.9247167, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_mse_objective": {"sum": 1.2285901308059692, "count": 1, "min": 1.2285901308059692, "max": 1.2285901308059692}}}
# #metrics {"StartTime": 1701647802.9247673, "EndTime": 1701647802.92478, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_mse_objective": {"sum": 1.2351078748703004, "count": 1, "min": 1.2351078748703004, "max": 1.2351078748703004}}}
# #metrics {"StartTime": 1701647802.9248266, "EndTime": 1701647802.924839, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"train_mse_objective": {"sum": 1.216660499572754, "count": 1, "min": 1.216660499572754, "max": 1.216660499572754}}}
# #metrics {"StartTime": 1701647802.9248877, "EndTime": 1701647802.9248989, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_mse_objective": {"sum": 0.9885608196258545, "count": 1, "min": 0.9885608196258545, "max": 0.9885608196258545}}}
# #metrics {"StartTime": 1701647802.9249449, "EndTime": 1701647802.9249558, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_mse_objective": {"sum": 1.0310339212417603, "count": 1, "min": 1.0310339212417603, "max": 1.0310339212417603}}}
# #metrics {"StartTime": 1701647802.925009, "EndTime": 1701647802.925022, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_mse_objective": {"sum": 0.9903002262115479, "count": 1, "min": 0.9903002262115479, "max": 0.9903002262115479}}}
# #metrics {"StartTime": 1701647802.9250758, "EndTime": 1701647802.9250891, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_mse_objective": {"sum": 0.9902682781219483, "count": 1, "min": 0.9902682781219483, "max": 0.9902682781219483}}}
# #metrics {"StartTime": 1701647802.9251394, "EndTime": 1701647802.9251518, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_mse_objective": {"sum": 1.3055196762084962, "count": 1, "min": 1.3055196762084962, "max": 1.3055196762084962}}}
# #metrics {"StartTime": 1701647802.9252024, "EndTime": 1701647802.925216, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 1.3512688398361206, "count": 1, "min": 1.3512688398361206, "max": 1.3512688398361206}}}
# #metrics {"StartTime": 1701647802.9252627, "EndTime": 1701647802.9252753, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 1.3556214332580567, "count": 1, "min": 1.3556214332580567, "max": 1.3556214332580567}}}
# #metrics {"StartTime": 1701647802.9253294, "EndTime": 1701647802.9253418, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 1.34106342792511, "count": 1, "min": 1.34106342792511, "max": 1.34106342792511}}}
# [12/03/2023 23:56:42 INFO 140583242454848] #quality_metric: host=algo-1, epoch=1, train mse_objective <loss>=0.9811383247375488
# #metrics {"StartTime": 1701647802.9721305, "EndTime": 1701647802.972197, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"validation_mse_objective": {"sum": 6665.146484375, "count": 1, "min": 6665.146484375, "max": 6665.146484375}}}
# #metrics {"StartTime": 1701647802.9722867, "EndTime": 1701647802.9723003, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"validation_mse_objective": {"sum": 6343.268229166667, "count": 1, "min": 6343.268229166667, "max": 6343.268229166667}}}
# #metrics {"StartTime": 1701647802.9723375, "EndTime": 1701647802.9723492, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"validation_mse_objective": {"sum": 6962.17578125, "count": 1, "min": 6962.17578125, "max": 6962.17578125}}}
# #metrics {"StartTime": 1701647802.9723997, "EndTime": 1701647802.9724119, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"validation_mse_objective": {"sum": 5961.697265625, "count": 1, "min": 5961.697265625, "max": 5961.697265625}}}
# #metrics {"StartTime": 1701647802.972461, "EndTime": 1701647802.9724724, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"validation_mse_objective": {"sum": 9492.7109375, "count": 1, "min": 9492.7109375, "max": 9492.7109375}}}
# #metrics {"StartTime": 1701647802.972529, "EndTime": 1701647802.972542, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"validation_mse_objective": {"sum": 10208.395833333334, "count": 1, "min": 10208.395833333334, "max": 10208.395833333334}}}
# #metrics {"StartTime": 1701647802.972595, "EndTime": 1701647802.9726074, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"validation_mse_objective": {"sum": 10098.266276041666, "count": 1, "min": 10098.266276041666, "max": 10098.266276041666}}}
# #metrics {"StartTime": 1701647802.9726622, "EndTime": 1701647802.9726753, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"validation_mse_objective": {"sum": 9065.034505208334, "count": 1, "min": 9065.034505208334, "max": 9065.034505208334}}}
# #metrics {"StartTime": 1701647802.9727283, "EndTime": 1701647802.9727404, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"validation_mse_objective": {"sum": 6981.967447916667, "count": 1, "min": 6981.967447916667, "max": 6981.967447916667}}}
# #metrics {"StartTime": 1701647802.9727867, "EndTime": 1701647802.9727988, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"validation_mse_objective": {"sum": 5981.33203125, "count": 1, "min": 5981.33203125, "max": 5981.33203125}}}
# #metrics {"StartTime": 1701647802.972839, "EndTime": 1701647802.9728477, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"validation_mse_objective": {"sum": 6460.955078125, "count": 1, "min": 6460.955078125, "max": 6460.955078125}}}
# #metrics {"StartTime": 1701647802.9728742, "EndTime": 1701647802.9728808, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"validation_mse_objective": {"sum": 6033.34765625, "count": 1, "min": 6033.34765625, "max": 6033.34765625}}}
# #metrics {"StartTime": 1701647802.9729142, "EndTime": 1701647802.972921, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"validation_mse_objective": {"sum": 9655.736979166666, "count": 1, "min": 9655.736979166666, "max": 9655.736979166666}}}
# #metrics {"StartTime": 1701647802.9729576, "EndTime": 1701647802.97297, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"validation_mse_objective": {"sum": 9826.212890625, "count": 1, "min": 9826.212890625, "max": 9826.212890625}}}
# #metrics {"StartTime": 1701647802.9730139, "EndTime": 1701647802.9730253, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"validation_mse_objective": {"sum": 9644.333984375, "count": 1, "min": 9644.333984375, "max": 9644.333984375}}}
# #metrics {"StartTime": 1701647802.9730694, "EndTime": 1701647802.9730804, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"validation_mse_objective": {"sum": 9850.253255208334, "count": 1, "min": 9850.253255208334, "max": 9850.253255208334}}}
# #metrics {"StartTime": 1701647802.973121, "EndTime": 1701647802.9731314, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"validation_mse_objective": {"sum": 6694.616536458333, "count": 1, "min": 6694.616536458333, "max": 6694.616536458333}}}
# #metrics {"StartTime": 1701647802.973186, "EndTime": 1701647802.973199, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"validation_mse_objective": {"sum": 6754.201171875, "count": 1, "min": 6754.201171875, "max": 6754.201171875}}}
# #metrics {"StartTime": 1701647802.9732466, "EndTime": 1701647802.9732583, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"validation_mse_objective": {"sum": 6364.456380208333, "count": 1, "min": 6364.456380208333, "max": 6364.456380208333}}}
# #metrics {"StartTime": 1701647802.9733117, "EndTime": 1701647802.9733253, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"validation_mse_objective": {"sum": 6250.556640625, "count": 1, "min": 6250.556640625, "max": 6250.556640625}}}
# #metrics {"StartTime": 1701647802.9733796, "EndTime": 1701647802.9733927, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"validation_mse_objective": {"sum": 7754.71875, "count": 1, "min": 7754.71875, "max": 7754.71875}}}
# #metrics {"StartTime": 1701647802.9734411, "EndTime": 1701647802.973453, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"validation_mse_objective": {"sum": 8671.048828125, "count": 1, "min": 8671.048828125, "max": 8671.048828125}}}
# #metrics {"StartTime": 1701647802.9734974, "EndTime": 1701647802.9735088, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"validation_mse_objective": {"sum": 7985.344401041667, "count": 1, "min": 7985.344401041667, "max": 7985.344401041667}}}
# #metrics {"StartTime": 1701647802.9735556, "EndTime": 1701647802.9735682, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"validation_mse_objective": {"sum": 8431.767578125, "count": 1, "min": 8431.767578125, "max": 8431.767578125}}}
# #metrics {"StartTime": 1701647802.9736183, "EndTime": 1701647802.9736319, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"validation_mse_objective": {"sum": 6817.586588541667, "count": 1, "min": 6817.586588541667, "max": 6817.586588541667}}}
# #metrics {"StartTime": 1701647802.9736788, "EndTime": 1701647802.9736917, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"validation_mse_objective": {"sum": 6749.1953125, "count": 1, "min": 6749.1953125, "max": 6749.1953125}}}
# ...
# #metrics {"StartTime": 1701647804.7349796, "EndTime": 1701647804.7349892, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 1.0009949684143067, "count": 1, "min": 1.0009949684143067, "max": 1.0009949684143067}}}
# #metrics {"StartTime": 1701647804.7350283, "EndTime": 1701647804.7350373, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 1.0110464215278625, "count": 1, "min": 1.0110464215278625, "max": 1.0110464215278625}}}
# #metrics {"StartTime": 1701647804.7350752, "EndTime": 1701647804.7350845, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 1.0062375783920288, "count": 1, "min": 1.0062375783920288, "max": 1.0062375783920288}}}
# [12/03/2023 23:56:44 INFO 140583242454848] #quality_metric: host=algo-1, epoch=11, train mse_objective <loss>=0.882599151134491
# #metrics {"StartTime": 1701647804.8001654, "EndTime": 1701647804.8002765, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 0}, "Metrics": {"validation_mse_objective": {"sum": 6309.811848958333, "count": 1, "min": 6309.811848958333, "max": 6309.811848958333}}}
# #metrics {"StartTime": 1701647804.8003826, "EndTime": 1701647804.8004012, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 1}, "Metrics": {"validation_mse_objective": {"sum": 6209.90234375, "count": 1, "min": 6209.90234375, "max": 6209.90234375}}}
# #metrics {"StartTime": 1701647804.8004563, "EndTime": 1701647804.8004715, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 2}, "Metrics": {"validation_mse_objective": {"sum": 6349.352864583333, "count": 1, "min": 6349.352864583333, "max": 6349.352864583333}}}
# #metrics {"StartTime": 1701647804.800602, "EndTime": 1701647804.8006237, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 3}, "Metrics": {"validation_mse_objective": {"sum": 5918.447916666667, "count": 1, "min": 5918.447916666667, "max": 5918.447916666667}}}
# #metrics {"StartTime": 1701647804.8007498, "EndTime": 1701647804.80077, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 4}, "Metrics": {"validation_mse_objective": {"sum": 6991.748697916667, "count": 1, "min": 6991.748697916667, "max": 6991.748697916667}}}
# #metrics {"StartTime": 1701647804.8008978, "EndTime": 1701647804.8009436, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 5}, "Metrics": {"validation_mse_objective": {"sum": 6941.033203125, "count": 1, "min": 6941.033203125, "max": 6941.033203125}}}
# #metrics {"StartTime": 1701647804.8009965, "EndTime": 1701647804.8011072, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 6}, "Metrics": {"validation_mse_objective": {"sum": 6921.688802083333, "count": 1, "min": 6921.688802083333, "max": 6921.688802083333}}}
# #metrics {"StartTime": 1701647804.8011785, "EndTime": 1701647804.8011959, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 7}, "Metrics": {"validation_mse_objective": {"sum": 7006.364583333333, "count": 1, "min": 7006.364583333333, "max": 7006.364583333333}}}
# #metrics {"StartTime": 1701647804.8012476, "EndTime": 1701647804.801261, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 8}, "Metrics": {"validation_mse_objective": {"sum": 6553.1875, "count": 1, "min": 6553.1875, "max": 6553.1875}}}
# #metrics {"StartTime": 1701647804.8013043, "EndTime": 1701647804.8013163, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 9}, "Metrics": {"validation_mse_objective": {"sum": 5955.393880208333, "count": 1, "min": 5955.393880208333, "max": 5955.393880208333}}}
# #metrics {"StartTime": 1701647804.8013594, "EndTime": 1701647804.801373, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 10}, "Metrics": {"validation_mse_objective": {"sum": 6064.893880208333, "count": 1, "min": 6064.893880208333, "max": 6064.893880208333}}}
# #metrics {"StartTime": 1701647804.8014247, "EndTime": 1701647804.8014374, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 11}, "Metrics": {"validation_mse_objective": {"sum": 6038.488932291667, "count": 1, "min": 6038.488932291667, "max": 6038.488932291667}}}
# #metrics {"StartTime": 1701647804.801484, "EndTime": 1701647804.8014965, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 12}, "Metrics": {"validation_mse_objective": {"sum": 6870.783854166667, "count": 1, "min": 6870.783854166667, "max": 6870.783854166667}}}
# #metrics {"StartTime": 1701647804.801563, "EndTime": 1701647804.801579, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 13}, "Metrics": {"validation_mse_objective": {"sum": 6930.743489583333, "count": 1, "min": 6930.743489583333, "max": 6930.743489583333}}}
# #metrics {"StartTime": 1701647804.8016348, "EndTime": 1701647804.8016496, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 14}, "Metrics": {"validation_mse_objective": {"sum": 6964.680989583333, "count": 1, "min": 6964.680989583333, "max": 6964.680989583333}}}
# #metrics {"StartTime": 1701647804.8017004, "EndTime": 1701647804.8017123, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 15}, "Metrics": {"validation_mse_objective": {"sum": 6846.28515625, "count": 1, "min": 6846.28515625, "max": 6846.28515625}}}
# #metrics {"StartTime": 1701647804.801755, "EndTime": 1701647804.8017676, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 16}, "Metrics": {"validation_mse_objective": {"sum": 6461.507161458333, "count": 1, "min": 6461.507161458333, "max": 6461.507161458333}}}
# #metrics {"StartTime": 1701647804.801815, "EndTime": 1701647804.8018289, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 17}, "Metrics": {"validation_mse_objective": {"sum": 6439.27734375, "count": 1, "min": 6439.27734375, "max": 6439.27734375}}}
# #metrics {"StartTime": 1701647804.8018742, "EndTime": 1701647804.8018866, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 18}, "Metrics": {"validation_mse_objective": {"sum": 6267.918619791667, "count": 1, "min": 6267.918619791667, "max": 6267.918619791667}}}
# #metrics {"StartTime": 1701647804.801933, "EndTime": 1701647804.8019457, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 19}, "Metrics": {"validation_mse_objective": {"sum": 6411.710286458333, "count": 1, "min": 6411.710286458333, "max": 6411.710286458333}}}
# #metrics {"StartTime": 1701647804.801991, "EndTime": 1701647804.8020043, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 20}, "Metrics": {"validation_mse_objective": {"sum": 6552.598307291667, "count": 1, "min": 6552.598307291667, "max": 6552.598307291667}}}
# #metrics {"StartTime": 1701647804.8020573, "EndTime": 1701647804.802071, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 21}, "Metrics": {"validation_mse_objective": {"sum": 6556.365885416667, "count": 1, "min": 6556.365885416667, "max": 6556.365885416667}}}
# #metrics {"StartTime": 1701647804.8021228, "EndTime": 1701647804.802137, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 22}, "Metrics": {"validation_mse_objective": {"sum": 6551.500651041667, "count": 1, "min": 6551.500651041667, "max": 6551.500651041667}}}
# #metrics {"StartTime": 1701647804.8021884, "EndTime": 1701647804.8022013, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 23}, "Metrics": {"validation_mse_objective": {"sum": 6602.936197916667, "count": 1, "min": 6602.936197916667, "max": 6602.936197916667}}}
# #metrics {"StartTime": 1701647804.8022668, "EndTime": 1701647804.8022807, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 24}, "Metrics": {"validation_mse_objective": {"sum": 6753.028645833333, "count": 1, "min": 6753.028645833333, "max": 6753.028645833333}}}
# #metrics {"StartTime": 1701647804.8023355, "EndTime": 1701647804.8023493, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 25}, "Metrics": {"validation_mse_objective": {"sum": 6744.522135416667, "count": 1, "min": 6744.522135416667, "max": 6744.522135416667}}}
# #metrics {"StartTime": 1701647804.8024023, "EndTime": 1701647804.8024156, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 26}, "Metrics": {"validation_mse_objective": {"sum": 6780.53515625, "count": 1, "min": 6780.53515625, "max": 6780.53515625}}}
# #metrics {"StartTime": 1701647804.802461, "EndTime": 1701647804.8024735, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 27}, "Metrics": {"validation_mse_objective": {"sum": 6750.294270833333, "count": 1, "min": 6750.294270833333, "max": 6750.294270833333}}}
# #metrics {"StartTime": 1701647804.8025203, "EndTime": 1701647804.802534, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 28}, "Metrics": {"validation_mse_objective": {"sum": 6733.571614583333, "count": 1, "min": 6733.571614583333, "max": 6733.571614583333}}}
# #metrics {"StartTime": 1701647804.8025875, "EndTime": 1701647804.8026016, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 29}, "Metrics": {"validation_mse_objective": {"sum": 6727.872395833333, "count": 1, "min": 6727.872395833333, "max": 6727.872395833333}}}
# #metrics {"StartTime": 1701647804.8026495, "EndTime": 1701647804.8026624, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 30}, "Metrics": {"validation_mse_objective": {"sum": 6739.873697916667, "count": 1, "min": 6739.873697916667, "max": 6739.873697916667}}}
# #metrics {"StartTime": 1701647804.8027084, "EndTime": 1701647804.8027215, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "model": 31}, "Metrics": {"validation_mse_objective": {"sum": 6747.537760416667, "count": 1, "min": 6747.537760416667, "max": 6747.537760416667}}}
# [12/03/2023 23:56:44 INFO 140583242454848] #quality_metric: host=algo-1, epoch=11, validation mse_objective <loss>=6309.811848958333
# [12/03/2023 23:56:44 INFO 140583242454848] #early_stopping_criteria_metric: host=algo-1, epoch=11, criteria=mse_objective, value=5918.447916666667
# [12/03/2023 23:56:44 INFO 140583242454848] Saving model for epoch: 11
# [12/03/2023 23:56:44 INFO 140583242454848] Saved checkpoint to "/tmp/tmpwpi5by2g/mx-mod-0000.params"
# [12/03/2023 23:56:44 INFO 140583242454848] Early stop condition met. Stopping training.
# [12/03/2023 23:56:44 INFO 140583242454848] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"StartTime": 1701647804.6155794, "EndTime": 1701647804.8100564, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 11, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 1216.0, "count": 1, "min": 1216, "max": 1216}, "Total Batches Seen": {"sum": 66.0, "count": 1, "min": 66, "max": 66}, "Max Records Seen Between Resets": {"sum": 92.0, "count": 1, "min": 92, "max": 92}, "Max Batches Seen Between Resets": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Reset Count": {"sum": 14.0, "count": 1, "min": 14, "max": 14}, "Number of Records Since Last Reset": {"sum": 92.0, "count": 1, "min": 92, "max": 92}, "Number of Batches Since Last Reset": {"sum": 5.0, "count": 1, "min": 5, "max": 5}}}
# [12/03/2023 23:56:44 INFO 140583242454848] #throughput_metric: host=algo-1, train throughput=472.62889156171997 records/second
# [12/03/2023 23:56:44 WARNING 140583242454848] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [12/03/2023 23:56:44 WARNING 140583242454848] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [12/03/2023 23:56:44 INFO 140583242454848] #early_stopping_criteria_metric: host=algo-1, epoch=11, criteria=mse_objective, value=5918.447916666667
# [12/03/2023 23:56:44 INFO 140583242454848] #validation_score (algo-1) : ('mse_objective', 5828.131510416667)
# [12/03/2023 23:56:44 INFO 140583242454848] #validation_score (algo-1) : ('mse', 5828.131510416667)
# [12/03/2023 23:56:44 INFO 140583242454848] #validation_score (algo-1) : ('absolute_loss', 64.85693868001302)
# [12/03/2023 23:56:44 INFO 140583242454848] #validation_score (algo-1) : ('rmse', 76.34220006272197)
# [12/03/2023 23:56:44 INFO 140583242454848] #validation_score (algo-1) : ('r2', 0.13343767487128688)
# [12/03/2023 23:56:44 INFO 140583242454848] #validation_score (algo-1) : ('mae', 64.85693804423015)
# [12/03/2023 23:56:44 INFO 140583242454848] #quality_metric: host=algo-1, validation mse_objective <loss>=5828.131510416667
# [12/03/2023 23:56:44 INFO 140583242454848] #quality_metric: host=algo-1, validation mse <loss>=5828.131510416667
# [12/03/2023 23:56:44 INFO 140583242454848] #quality_metric: host=algo-1, validation absolute_loss <loss>=64.85693868001302
# [12/03/2023 23:56:44 INFO 140583242454848] #quality_metric: host=algo-1, validation rmse <loss>=76.34220006272197
# [12/03/2023 23:56:44 INFO 140583242454848] #quality_metric: host=algo-1, validation r2 <loss>=0.13343767487128688
# [12/03/2023 23:56:44 INFO 140583242454848] #quality_metric: host=algo-1, validation mae <loss>=64.85693804423015
# [12/03/2023 23:56:44 INFO 140583242454848] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.005, "wd": 0.0001, "l1": 0.0, "lr_scheduler_step": 100, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 0.0001}
# [12/03/2023 23:56:44 INFO 140583242454848] Saved checkpoint to "/tmp/tmp7b_ichy4/mx-mod-0000.params"
# [12/03/2023 23:56:44 INFO 140583242454848] Test data is not provided.
# #metrics {"StartTime": 1701647802.431481, "EndTime": 1701647804.887618, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 217.8030014038086, "count": 1, "min": 217.8030014038086, "max": 217.8030014038086}, "epochs": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "check_early_stopping.time": {"sum": 9.958744049072266, "count": 13, "min": 0.2522468566894531, "max": 1.3852119445800781}, "update.time": {"sum": 2112.2353076934814, "count": 12, "min": 161.93747520446777, "max": 223.89507293701172}, "finalize.time": {"sum": 69.32687759399414, "count": 1, "min": 69.32687759399414, "max": 69.32687759399414}, "setuptime": {"sum": 4.352569580078125, "count": 1, "min": 4.352569580078125, "max": 4.352569580078125}, "totaltime": {"sum": 2605.618715286255, "count": 1, "min": 2605.618715286255, "max": 2605.618715286255}}}
#
# 2023-12-03 23:57:02 Completed - Training job completed
# Training seconds: 157
# Billable seconds: 157

# %%
linear_predictor = linear.deploy(initial_instance_count=1, instance_type="ml.m4.xlarge")
from sagemaker.serializers import CSVSerializer
linear_predictor.serializer = CSVSerializer()
num_features = 5  
sample_data = np.random.rand(num_features)
result = linear_predictor.predict(sample_data, initial_args={"ContentType": "text/csv"})
print(result)
# Out:
# INFO:sagemaker:Creating model with name: linear-learner-2023-12-04-00-44-44-984
# INFO:sagemaker:Creating endpoint-config with name linear-learner-2023-12-04-00-44-44-984
# INFO:sagemaker:Creating endpoint with name linear-learner-2023-12-04-00-44-44-984
# --------!b'{"predictions": [{"score": 47.478424072265625}]}'

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Assuming y_true are the true labels and y_pred are model predictions
y_true = [0.35,0.074,375,105,0]  # Replace with your actual data
y_pred = [0.16,0.038,275,113,1]  # Replace with your actual data

mse = mean_squared_error(y_true, y_pred)
mae = mean_absolute_error(y_true, y_pred)
r2 = r2_score(y_true, y_pred)

print("MSE:", mse)
print("Mean Absolute Error (MAE):", mae)
print("R-squared (R2):", r2)
# Out:
# MSE: 2013.0074792
# Mean Absolute Error (MAE): 21.8452
# R-squared (R2): 0.9045865678444202

# %%
import sagemaker
from sagemaker.amazon.amazon_estimator import get_image_uri
from sagemaker.estimator import Estimator

# Get the Linear Learner image URI
linear_learner_image = get_image_uri(sagemaker.Session().boto_region_name, 'linear-learner')

# Define the estimator
estimator = Estimator(
    image_uri=linear_learner_image,
    role=sagemaker.get_execution_role(),
    instance_count=1,
    instance_type='ml.m4.xlarge',
    output_path='s3://cosyneraw/ttv/output'
)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.0' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# The method get_image_uri has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml

# %%
from sagemaker.tuner import IntegerParameter

hyperparameter_ranges = {
    'mini_batch_size': IntegerParameter(32, 512)
}

# %%
objective_metric_name = 'test:mse'

# %%
from sagemaker.tuner import HyperparameterTuner

# Create a HyperparameterTuner object
tuner = HyperparameterTuner(
    estimator=estimator,
    objective_metric_name=objective_metric_name,
    hyperparameter_ranges=hyperparameter_ranges,
    max_jobs=1,  # Total number of training jobs
    max_parallel_jobs=1,  # Number of jobs to run in parallel
    objective_type='Minimize'  # Minimize MSE
)

# Start the tuning job
tuner.fit({'train': 's3://cosyneraw/ttv/train', 'validation': 's3://cosyneraw/ttv/validate'})
# Out:
# No finished training job found associated with this estimator. Please make sure this estimator is only used for building workflow config
# No finished training job found associated with this estimator. Please make sure this estimator is only used for building workflow config
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[5], line 14
#       4 tuner = HyperparameterTuner(
#       5     estimator=estimator,
#       6     objective_metric_name=objective_metric_name,
#    (...)
#      10     objective_type='Minimize'  # Minimize MSE
#      11 )
#      13 # Start the tuning job
# ---> 14 tuner.fit({'train': 's3://cosyneraw//ttv/train', 'validation': 's3://cosyneraw/ttv/validate'})
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/workflow/pipeline_context.py:311, in runnable_by_pipeline.<locals>.wrapper(*args, **kwargs)
#     307         return context
#     309     return _StepArguments(retrieve_caller_name(self_instance), run_func, *args, **kwargs)
# --> 311 return run_func(*args, **kwargs)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/tuner.py:1029, in HyperparameterTuner.fit(self, inputs, job_name, include_cls_metadata, estimator_kwargs, wait, **kwargs)
#     970 """Start a hyperparameter tuning job.
#     971
#     972 Args:
#    (...)
#    1026         arguments are needed.
#    1027 """
#    1028 if self.estimator is not None:
# -> 1029     self._fit_with_estimator(inputs, job_name, include_cls_metadata, **kwargs)
#    1030 else:
#    1031     self._fit_with_estimator_dict(inputs, job_name, include_cls_metadata, estimator_kwargs)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/tuner.py:1040, in HyperparameterTuner._fit_with_estimator(self, inputs, job_name, include_cls_metadata, **kwargs)
#    1038 self._prepare_estimator_for_tuning(self.estimator, inputs, job_name, **kwargs)
#    1039 self._prepare_for_tuning(job_name=job_name, include_cls_metadata=include_cls_metadata)
# -> 1040 self.latest_tuning_job = _TuningJob.start_new(self, inputs)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/tuner.py:2138, in _TuningJob.start_new(cls, tuner, inputs)
#    2121 """Create a new Amazon SageMaker HyperParameter Tuning job.
#    2122
#    2123 The new HyperParameter Tuning job uses the provided `tuner` and `inputs`
#    (...)
#    2134     information about the started job.
#    2135 """
#    2136 tuner_args = cls._get_tuner_args(tuner, inputs)
# -> 2138 tuner.sagemaker_session.create_tuning_job(**tuner_args)
#    2140 return cls(tuner.sagemaker_session, tuner._current_job_name)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/session.py:2925, in Session.create_tuning_job(self, job_name, tuning_config, training_config, training_config_list, warm_start_config, tags, autotune)
#    2922     LOGGER.debug("tune request: %s", json.dumps(request, indent=4))
#    2923     self.sagemaker_client.create_hyper_parameter_tuning_job(**request)
# -> 2925 self._intercept_create_request(tune_request, submit, self.create_tuning_job.__name__)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/session.py:5618, in Session._intercept_create_request(self, request, create, func_name)
#    5601 def _intercept_create_request(
#    5602     self,
#    5603     request: typing.Dict,
#    (...)
#    5606     # pylint: disable=unused-argument
#    5607 ):
#    5608     """This function intercepts the create job request.
#    5609
#    5610     PipelineSession inherits this Session class and will override
#    (...)
#    5616         func_name (str): the name of the function needed intercepting
#    5617     """
# -> 5618     return create(request)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/session.py:2923, in Session.create_tuning_job.<locals>.submit(request)
#    2921 LOGGER.info("Creating hyperparameter tuning job with name: %s", job_name)
#    2922 LOGGER.debug("tune request: %s", json.dumps(request, indent=4))
# -> 2923 self.sagemaker_client.create_hyper_parameter_tuning_job(**request)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/botocore/client.py:535, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     531     raise TypeError(
#     532         f"{py_operation_name}() only accepts keyword arguments."
#     533     )
#     534 # The "self" in this scope is referring to the BaseClient.
# --> 535 return self._make_api_call(operation_name, kwargs)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/botocore/client.py:980, in BaseClient._make_api_call(self, operation_name, api_params)
#     978     error_code = parsed_response.get("Error", {}).get("Code")
#     979     error_class = self.exceptions.from_code(error_code)
# --> 980     raise error_class(parsed_response, operation_name)
#     981 else:
#     982     return parsed_response
#
# ClientError: An error occurred (ValidationException) when calling the CreateHyperParameterTuningJob operation: No S3 objects found under S3 URL "s3://cosyneraw//ttv/train" given in input data source. Please ensure that the bucket exists in the selected region (us-east-1), that objects exist under that S3 prefix, and that the role "arn:aws:iam::153395555780:role/LabRole" has "s3:ListBucket" permissions on bucket "cosyneraw".
